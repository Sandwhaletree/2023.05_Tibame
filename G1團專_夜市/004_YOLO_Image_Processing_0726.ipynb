# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandwhaletree/2023.05_Tibame/blob/main/G1%E5%9C%98%E5%B0%88_%E5%A4%9C%E5%B8%82/004_YOLO_Image_Processing_0726.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#查看目前路徑
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/machi'

# %%
#查看資料夾內檔案個數
import os

r="/content/drive/MyDrive/machi"

os.chdir(r) #更改路徑至想要路徑
folder_path = r #設定資料夾路徑

# 取得資料夾中的檔案列表
file_list = os.listdir(folder_path)

# 印出資料夾中的檔案數量
print(f"資料夾中有 {len(file_list)} 個檔案")
# Out:
# 資料夾中有 300 個檔案

# %%
#查看資料夾內檔案格式個數
import cv2
from glob import glob

paths_JPG = sorted(glob('/content/drive/MyDrive/machi/*.JPG'))
paths_png = sorted(glob('/content/drive/MyDrive/machi/*.png'))
paths_jpg = sorted(glob('/content/drive/MyDrive/machi/*.jpg'))

# 你可以使用len()函數來計算每個列表的長度，這將給出每種類型的文件數量。
print("Number of .JPG files: ", len(paths_JPG))
print("Number of .png files: ", len(paths_png))
print("Number of .jpg files: ", len(paths_jpg))
# Out:
# Number of .JPG files:  0
# Number of .png files:  0
# Number of .jpg files:  300

# %%
#cv2.IMWRITE_JPEG_QUALITY 0~100
for i in range(0, len(paths_JPG)):
  img = cv2.imread(paths_JPG[i])[:,:,::-1]
  cv2.imwrite(f"/content/drive/MyDrive/machi/machi_0_{i:03}.jpg", img[:,:,::-1], [cv2.IMWRITE_JPEG_QUALITY, 20])
for i in range(0, len(paths_png)):
  img = cv2.imread(paths_png[i])[:,:,::-1]
  cv2.imwrite(f"/content/drive/MyDrive/machi/machi_1_{i:03}.jpg", img[:,:,::-1], [cv2.IMWRITE_JPEG_QUALITY, 40])
#jpg 可改可不改 Quality
for i in range(0, len(paths_jpg)):
  img = cv2.imread(paths_jpg[i])[:,:,::-1]
  cv2.imwrite(f"/content/drive/MyDrive/machi/machi_2_{i:03}.jpg", img[:,:,::-1])

# %%
#快速更改檔名
import os

# The directory that contains your .MOV files
input_dir = folder_path

# Get a list of all .MOV files in the input directory
input_files = [f for f in os.listdir(input_dir) if f.endswith('.jpg')]

# Sort the input files to ensure they are processed in order
input_files.sort()

# Loop over each input file
for i, input_file in enumerate(input_files, start=1):
    # Define the full path of the input file
    input_path = os.path.join(input_dir, input_file)

    # Define the new name of the file
    new_file = "machi_{:003d}.jpg".format(i)

    # Define the full path of the new file
    new_path = os.path.join(input_dir, new_file)

    # Rename the input file to the new file
    os.rename(input_path, new_path)

    # Print the new file name
    print(new_file)
# Out:
# machi_001.jpg
# machi_002.jpg
# machi_003.jpg
# machi_004.jpg
# machi_005.jpg
# machi_006.jpg
# machi_007.jpg
# machi_008.jpg
# machi_009.jpg
# machi_010.jpg
# machi_011.jpg
# machi_012.jpg
# machi_013.jpg
# machi_014.jpg
# machi_015.jpg
# machi_016.jpg
# machi_017.jpg
