# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandwhaletree/2023.05_Tibame/blob/main/A13_%E5%B0%88%E9%A1%8C%E5%AF%A6%E4%BD%9C%E6%8C%87%E5%B0%8E_%E9%99%B3%E5%AE%87%E6%98%A5/C09_Data_Visualization_Day_3_%E7%AF%84%E4%BE%8B_0731.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **主要目標:**
#     了解各種Seaborn 的圖示化套件如何使用
#
# 溫馨叮嚀: 不熟悉使用沒關係, 提出來, 有專家陪跑

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Seaborn圖樣式
# 有五種預設seaborn主題：darkgrid，whitegrid，dark，white，和ticks。它們各自適合不同的應用和個人喜好。默認主題是darkgrid

# %%
#設定資料
#宣告一個 sin 正弦波
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
#設定圖樣
sns.set_style("darkgrid")
#繪圖
sinplot()

# %% [markdown]
# # 暫時設定圖形樣式
# 雖然來回切換很容易，但您也可以axes_style()在with語句中使用該功能來臨時設置繪圖參數。
# 這也允許您使用不同風格的軸製作圖形

# %%
#宣告一個 sin 正弦波
sns.set_style("dark")
#繪圖
sinplot()

# %%
#宣告一個 sin 正弦波
sns.set_style("whitegrid")
#繪圖
sinplot()

# %%
#宣告一個 sin 正弦波
sns.set_style("white")
#繪圖
sinplot()

# %%
#宣告一個 sin 正弦波
sns.set_style("ticks")
#繪圖
sinplot()

# %% [markdown]
# 統計關係
# 統計分析是一個了解數據集中變數之間如何相互關聯以及這些關係如何依賴於其他變數的過程。
#
# 散點圖關聯變量
# 將變數與散點圖關聯 散點圖是統計視覺化的支柱。它使用點圖描繪了兩個變數的聯合分佈,其中每個點表示數據集中的觀測值。
# 這種描述允許眼睛推斷出大量有關它們之間是否有任何有意義的關係的資訊。
# # 使用 relplot

# %%
sns.set(style="darkgrid")

# %%
# 載入數據集
tips = sns.load_dataset("tips")
fmri = sns.load_dataset("fmri")

# %%
#觀看資料集有哪些變數
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 套用 x/y 的變數
# relplot, relationship plot, 關聯式繪圖, 初始設定使用點圖
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
#當點以兩個維度繪製時,可以通過根據第三個變數對點進行著色,將另一個維度添加到繪圖中。這稱為使用「色調語義」,因為點的顏色獲得意義:
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
# 通過獨立地改變每個點的色調和样式，也可以表示四個變量
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);

# %%
# 在關聯式繪圖裡, 另一個是可以使用回歸
# regplot, regression plot, 參數的定義與 relplot 相同
sns.regplot(x="total_bill", y="tip", data=tips);
